# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarsakthi835/Python-While-Loop-For-Loop-and-Function/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Random number between 1 and 10
secret_number = random.randint(1, 10)

#Maximum number of attempts
attempts = 3

print("Welcome to the Number Guessing Game!")
print("You have 3 attempts to guess the number.")

while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))

    # Check if the guess is out of range
    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue

    # Reduce the attempts for a valid guess
    attempts -= 1

    # Check if the guess is correct
    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break
    elif guess > secret_number:
        print("Too high. Try again.")
    else:
        print("Too low. Try again.")

else:
    print("Better luck next time! The correct number was", secret_number)
# Out:
# Welcome to the Number Guessing Game!
# You have 3 attempts to guess the number.
# Guess the number (between 1 and 10): 2
# Too low. Try again.
# Guess the number (between 1 and 10): 10
# Too high. Try again.
# Guess the number (between 1 and 10): 17
# Your guess is out of range. Please guess a number between 1 and 10.
# Guess the number (between 1 and 10): 6
# Too high. Try again.
# Better luck next time! The correct number was 5

# %%
#Number from the user
number = int(input("Enter the number for which you want the multiplication table: "))

# Multiplication table from 1 to 10
for i in range(1, 11):
    result = number * i
    print(number, "x", i, "=", result)
# Out:
# Enter the number for which you want the multiplication table: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
# Function to calculate BMI
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi

# Input from the user
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

# Calculate BMI
bmi = calculate_bmi(weight, height)

# Display the BMI
print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 70
# Enter your height in meters: 1.75
# Your BMI is: 22.86
